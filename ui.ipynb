# %% [markdown]
# <header class="bh-header bh-header--advanced" id="bifrostHeader">
#     <div class="bh-headerContent">
#         <h2 class="bh-headerContent-title" id="bifrostHeader-title">
#             <b>BioCanvas</b>: Comprehensive data analysis and visualization platform for multi-modality biological data
#         </h2>
#         <div class="bh-Version"><i>Version: 0.1.0</i></div>
#         <div class="bh-headerDescription" id="Header-description">
#             BioConvas enables users to process, consolidate, analyze, and visualize fermentation, bioanalytical, biochemistry, and process results from selected projects, including statistical workflows. This release supports shake flasks, 0.3 L (Multifors), 2 L (Labfors), and 10 L and 40 L tanks.
#         </div>
#         <div class="bh-headerAuthor" id="Header-author">
#             Developed by Payman Tohidifar
#         </div>
#     </div>
#     <!-- <figure class="bh-headerLogo"></figure> -->
# </header>

# %%
# %load_ext autoreload
# %autoreload 2

print('testing ...')
# import sys
# import os

# from src.biocanvas.core import App


# if __name__ == "__main__":

#     # Create an App instance and display it
#     # Logs are written to the project logs directory (biosynic_debug.log, meta_qc.log)
#     app = App()
#     app.display()
# Out:
# testing ...
